# %%
# !pip install ultralytics
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 54.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 4.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 69.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 36.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 46.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 2.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 5.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 13.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 7.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 6.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 188.7/188.7 MB 5.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 23.2 MB/s eta 0:00:00
# ...

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
from ultralytics import YOLO
import cv2
import numpy as np
from google.colab.patches import cv2_imshow
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.

# %% [markdown]
# ### Object Detection

# %%
# %cd /content/Football
# Out:
# /content/Football

# %%
# !unzip /content/foot.zip
# Out:
# Archive:  /content/foot.zip
#   inflating: README.dataset.txt
#   inflating: README.roboflow.txt
#   inflating: data.yaml
#    creating: test/
#    creating: test/images/
#  extracting: test/images/youtube-104_jpg.rf.08e90535310b0ae6fb1b40af72fc0fce.jpg
#  extracting: test/images/youtube-105_jpg.rf.adc7001a2707d28e56f3bd5ff7b12777.jpg
#  extracting: test/images/youtube-10_jpg.rf.021c76b2cc1566c0398b2b47051fdd2f.jpg
#  extracting: test/images/youtube-141_jpg.rf.39c13e3dfe5271ca8bc0417cee7cc7ee.jpg
#  extracting: test/images/youtube-157_jpg.rf.7636f822bb86b7b04098bf4dfa42b279.jpg
#  extracting: test/images/youtube-167_jpg.rf.2e76d8c7d242e9d8d71c6fd5e9f44659.jpg
#  extracting: test/images/youtube-170_jpg.rf.69a79fb12d920a8ecff0fbe9f21a732f.jpg
#  extracting: test/images/youtube-171_jpg.rf.43cf74dcc985a029badcaa8ec51ff3af.jpg
#  extracting: test/images/youtube-173_jpg.rf.7861ddb929d03a449d075b439a581dc2.jpg
# ...

# %%
# Load a COCO-pretrained YOLO11n model
model = YOLO("yolo11n.pt")

# %%
# Train the model on the COCO8 example dataset for 100 epochs
results = model.train(data="data.yaml", epochs=50, imgsz=640, name='yolo11n_Football_Players_Detection')
# Out:
# Ultralytics 8.3.176 🚀 Python-3.11.13 torch-2.6.0+cu124 CUDA:0 (Tesla T4, 15095MiB)
# ...

# %% [markdown]
# #### Inference on image

# %%
model
# Out:
# YOLO(
#   (model): DetectionModel(
#     (model): Sequential(
#       (0): Conv(
#         (conv): Conv2d(3, 16, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#         (bn): BatchNorm2d(16, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#         (act): SiLU(inplace=True)
#       )
#       (1): Conv(
#         (conv): Conv2d(16, 32, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#         (bn): BatchNorm2d(32, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#         (act): SiLU(inplace=True)
#       )
#       (2): C3k2(
#         (cv1): Conv(
#           (conv): Conv2d(32, 32, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(32, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#           (act): SiLU(inplace=True)
#         )
#         (cv2): Conv(
#           (conv): Conv2d(48, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
# ...

# %%
# Function for inference on a single image

def infer_image(image_path, output_path="output_image.jpg"):
    # Read the image
    img = cv2.imread(image_path)
    if img is None:
        print(f"Error: Could not load image at {image_path}")
        return

    # Perform inference
    results = model(img)

    # Draw bounding boxes and labels on the image
    annotated_img = results[0].plot()

    # Save the output image
    # cv2.imwrite(output_path, annotated_img)
    cv2_imshow(annotated_img)
    print(f"Output image saved at {output_path}")

# %%
image_path = "/content/football.jfif"

# %%
# Run inference on image
infer_image(image_path, "output_image.jpg")
# Out:
# 0: 384x640 7 players, 1 referee, 51.8ms
# Speed: 2.1ms preprocess, 51.8ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
# <PIL.Image.Image image mode=RGB size=295x171>
# Output image saved at output_image.jpg

# %% [markdown]
# #### Inferencing on video

# %%
# Function for inference on a video
def infer_video(video_path, output_path="output_video.mp4"):
    # Open the video file
    cap = cv2.VideoCapture(video_path)
    if not cap.isOpened():
        print(f"Error: Could not open video at {video_path}")
        return

    # Get video properties
    width = int(cap.get(cv2.CAP_PROP_FRAME_WIDTH))
    height = int(cap.get(cv2.CAP_PROP_FRAME_HEIGHT))
    fps = int(cap.get(cv2.CAP_PROP_FPS))

    # Define the codec and create VideoWriter object
    fourcc = cv2.VideoWriter_fourcc(*'mp4v')
    out = cv2.VideoWriter(output_path, fourcc, fps, (width, height))

    # Process video frame by frame
    while cap.isOpened():
        ret, frame = cap.read()
        if not ret:
            break

        # Perform inference on the frame
        results = model(frame)

        # Draw bounding boxes and labels on the frame
        annotated_frame = results[0].plot()

        # Write the frame to the output video
        out.write(annotated_frame)

    # Release resources
    cap.release()
    out.release()
    cv2.destroyAllWindows()
    print(f"Output video saved at {output_path}")

# %%
# Run inference on image
video_path = "/content/simple.mp4"

# %%
# Run inference on video
infer_video(video_path, "output_video.mp4")
# Out:
# 0: 384x640 3 balls, 4 players, 19.8ms
# Speed: 4.4ms preprocess, 19.8ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 balls, 4 players, 14.4ms
# Speed: 4.6ms preprocess, 14.4ms inference, 2.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 balls, 4 players, 10.9ms
# Speed: 2.5ms preprocess, 10.9ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 balls, 5 players, 10.5ms
# Speed: 2.8ms preprocess, 10.5ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 balls, 4 players, 10.9ms
# Speed: 2.6ms preprocess, 10.9ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 balls, 4 players, 11.1ms
# Speed: 2.3ms preprocess, 11.1ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 balls, 3 players, 11.2ms
# Speed: 2.6ms preprocess, 11.2ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# ...

# %%
import cv2

def infer_video(video_path, output_path="output_video.mp4"):
    # Open the video file
    cap = cv2.VideoCapture(video_path)
    if not cap.isOpened():
        print(f"Error: Could not open video at {video_path}")
        return

    # Get video properties
    width = int(cap.get(cv2.CAP_PROP_FRAME_WIDTH))
    height = int(cap.get(cv2.CAP_PROP_FRAME_HEIGHT))
    fps = int(cap.get(cv2.CAP_PROP_FPS))

    # Define the codec and create VideoWriter object
    fourcc = cv2.VideoWriter_fourcc(*'mp4v')
    out = cv2.VideoWriter(output_path, fourcc, fps, (width, height))

    # Process video frame by frame
    while cap.isOpened():
        ret, frame = cap.read()
        if not ret:
            break

        # Perform inference on the frame
        results = model(frame)

        # Get the annotated frame (with bounding boxes)
        annotated_frame = results[0].plot()

        # Access detection results (boxes, scores, and classes)
        detections = results[0].boxes  # Assuming YOLO-like model output
        for box in detections:
            # Extract coordinates, confidence, and class ID
            x1, y1, x2, y2 = box.xyxy[0].cpu().numpy().astype(int)  # Bounding box coordinates
            conf = box.conf[0].cpu().numpy()  # Confidence score
            cls = int(box.cls[0].cpu().numpy())  # Class ID
            label = f"{model.names[cls]} {conf:.2f}"  # Class name and confidence score

            # Define text properties
            font = cv2.FONT_HERSHEY_SIMPLEX
            font_scale = 0.5
            color = (255, 255, 255)  # White text
            thickness = 1
            text_size = cv2.getTextSize(label, font, font_scale, thickness)[0]
            text_x = x1
            text_y = y1 - 10 if y1 - 10 > 10 else y1 + 10  # Place text above or below box

            # Draw text background for better visibility
            cv2.rectangle(
                annotated_frame,
                (text_x, text_y - text_size[1]),
                (text_x + text_size[0], text_y),
                (0, 0, 0),  # Black background
                cv2.FILLED,
            )

            # Draw text on the frame
            cv2.putText(
                annotated_frame,
                label,
                (text_x, text_y),
                font,
                font_scale,
                color,
                thickness,
                cv2.LINE_AA,
            )

        # Write the frame to the output video
        out.write(annotated_frame)

    # Release resources
    cap.release()
    out.release()
    cv2.destroyAllWindows()
    print(f"Output video saved at {output_path}")

# %%
# Run inference on video
infer_video('/content/simple.mp4', "output_video_10000.mp4")
# Out:
# 0: 384x640 3 balls, 4 players, 12.6ms
# Speed: 4.0ms preprocess, 12.6ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 balls, 4 players, 10.7ms
# Speed: 2.1ms preprocess, 10.7ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 balls, 4 players, 9.5ms
# Speed: 2.2ms preprocess, 9.5ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 balls, 5 players, 9.8ms
# Speed: 2.1ms preprocess, 9.8ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 balls, 4 players, 15.8ms
# Speed: 2.0ms preprocess, 15.8ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 balls, 4 players, 15.2ms
# Speed: 2.4ms preprocess, 15.2ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 balls, 3 players, 17.3ms
# Speed: 2.2ms preprocess, 17.3ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
#
# ...

# %% [markdown]
# ### Segmentation

# %%
# %cd /content/Lab_11_task
# Out:
# /content/Lab_11_task

# %% [markdown]
# **Dataset link** : `https://app.roboflow.com/diffusion-93yax/car-damage-coco-dataset-qafqr/1`

# %%
# !unzip /content/Lab_11/car-damage-coco-dataset.v2i.yolov11.zip
# Out:
# unzip:  cannot find or open /content/Lab_11/car-damage-coco-dataset.v2i.yolov11.zip, /content/Lab_11/car-damage-coco-dataset.v2i.yolov11.zip.zip or /content/Lab_11/car-damage-coco-dataset.v2i.yolov11.zip.ZIP.

# %% [markdown]
# below code: to convert coco format to yolo format

# %%
import json
import os

def convert_coco_to_yolo_segmentation(json_file, folder_name = "labels"):
    folder_name = folder_name
    # Load the JSON file
    with open(json_file, 'r') as file:
        coco_data = json.load(file)

    # Create a "labels" folder to store YOLO segmentation annotations
    output_folder = os.path.join(os.path.dirname(json_file), folder_name)
    os.makedirs(output_folder, exist_ok=True)

    # Extract annotations from the COCO JSON data
    annotations = coco_data['annotations']
    for annotation in annotations:
        image_id = annotation['image_id']
        category_id = annotation['category_id']
        segmentation = annotation['segmentation']
        bbox = annotation['bbox']

        # Find the image filename from the COCO data
        for image in coco_data['images']:
            if image['id'] == image_id:
                image_filename = os.path.basename(image['file_name'])
                image_filename = os.path.splitext(image_filename)[0] # Removing the extension. (In our case, it is the .jpg or .png part.)
                image_width = image['width']
                image_height = image['height']
                break

        # Calculate the normalized center coordinates and width/height
        x_center = (bbox[0] + bbox[2] / 2) / image_width
        y_center = (bbox[1] + bbox[3] / 2) / image_height
        bbox_width = bbox[2] / image_width
        bbox_height = bbox[3] / image_height

        # Convert COCO segmentation to YOLO segmentation format
        yolo_segmentation = [f"{(x) / image_width:.5f} {(y) / image_height:.5f}" for x, y in zip(segmentation[0][::2], segmentation[0][1::2])]
        #yolo_segmentation.append(f"{(segmentation[0][0]) / image_width:.5f} {(segmentation[0][1]) / image_height:.5f}")
        yolo_segmentation = ' '.join(yolo_segmentation)

        # Generate the YOLO segmentation annotation line
        yolo_annotation = f"{category_id} {yolo_segmentation}"

        # Save the YOLO segmentation annotation in a file
        output_filename = os.path.join(output_folder, f"{image_filename}.txt")
        with open(output_filename, 'a+') as file:
            file.write(yolo_annotation + '\n')

    print("Conversion completed. YOLO segmentation annotations saved in 'labels' folder.")




# Example usage
json_file = "/content/Car_Demage_Segmentation/train/_annotations.coco.json" #JSON file
split = "/content/Car_Demage_Segmentation/output_folder_train" #Folder
convert_coco_to_yolo_segmentation(json_file, split)
# Out:
# Conversion completed. YOLO segmentation annotations saved in 'labels' folder.

# %%
# Load a COCO-pretrained YOLO11n model
model = YOLO("yolo11n-seg.pt")

# %%
# Train the model
results = model.train(data="/content/Lab_11/data.yaml", epochs=20, imgsz=640, name='cat_dog_segmentation_experiment_01')
# Out:
# Ultralytics 8.3.176 🚀 Python-3.11.13 torch-2.6.0+cu124 CUDA:0 (Tesla T4, 15095MiB)
# ...

# %%
from ultralytics import YOLO

# Load a pretrained model
model = YOLO("/content/Lab_11/runs/segment/cat_dog_segmentation_experiment_01/weights/best.pt")

# Validate the model
metrics = model.val()
print("Mean Average Precision for boxes:", metrics.box.map)
print("Mean Average Precision for masks:", metrics.seg.map)
# Out:
# Ultralytics 8.3.176 🚀 Python-3.11.13 torch-2.6.0+cu124 CUDA:0 (Tesla T4, 15095MiB)
# YOLO11n-seg summary (fused): 113 layers, 2,834,763 parameters, 0 gradients, 10.2 GFLOPs
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 1106.1±937.5 MB/s, size: 63.9 KB)
# val: Scanning /content/Lab_11/valid/labels.cache... 346 images, 0 backgrounds, 0 corrupt: 100%|██████████| 346/346 [00:00<?, ?it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95):   0%|          | 0/22 [00:00<?, ?it/s]
# WARNING ⚠️ Limiting validation plots to first 50 items per image for speed...
# WARNING ⚠️ Limiting validation plots to first 50 items per image for speed...
# WARNING ⚠️ Limiting validation plots to first 50 items per image for speed...
# WARNING ⚠️ Limiting validation plots to first 50 items per image for speed...
# WARNING ⚠️ Limiting validation plots to first 50 items per image for speed...
# ...

# %% [markdown]
# setting for local system

# %%
from ultralytics import YOLO

# Load a model
model = YOLO("/content/Lab_11/runs/segment/cat_dog_segmentation_experiment_01/weights/best.pt")  # load a custom model

# %%
# Function for inference on a single image

def infer_image(image_path, output_path="output_image.jpg"):
    # Read the image
    img = cv2.imread(image_path)
    if img is None:
        print(f"Error: Could not load image at {image_path}")
        return

    # Perform inference
    results = model(img)

    # Draw bounding boxes and labels on the image
    annotated_img = results[0].plot()

    # Save the output image
    # cv2.imwrite(output_path, annotated_img)
    cv2_imshow(annotated_img)
    print(f"Output image saved at {output_path}")

# %%
infer_image("/content/Lab_11/test/images/46_jpg.rf.299c105f756bef5e5a608dd954c3afb9.jpg", "  segmented_out.jpg")
# Out:
# 0: 480x640 1 Car-Damage, 205.7ms
# Speed: 3.5ms preprocess, 205.7ms inference, 17.5ms postprocess per image at shape (1, 3, 480, 640)
# <PIL.Image.Image image mode=RGB size=260x194>
# Output image saved at   segmented_out.jpg

# %%
# Function for inference on a video
def infer_video(video_path, output_path="output_video.mp4"):
    # Open the video file
    cap = cv2.VideoCapture(video_path)
    if not cap.isOpened():
        print(f"Error: Could not open video at {video_path}")
        return

    # Get video properties
    width = int(cap.get(cv2.CAP_PROP_FRAME_WIDTH))
    height = int(cap.get(cv2.CAP_PROP_FRAME_HEIGHT))
    fps = int(cap.get(cv2.CAP_PROP_FPS))

    # Define the codec and create VideoWriter object
    fourcc = cv2.VideoWriter_fourcc(*'mp4v')
    out = cv2.VideoWriter(output_path, fourcc, fps, (width, height))

    # Process video frame by frame
    while cap.isOpened():
        ret, frame = cap.read()
        if not ret:
            break

        # Perform inference on the frame
        results = model(frame)

        # Draw bounding boxes and labels on the frame
        annotated_frame = results[0].plot()

        # Write the frame to the output video
        out.write(annotated_frame)

    # Release resources
    cap.release()
    out.release()
    cv2.destroyAllWindows()
    print(f"Output video saved at {output_path}")

# %%
infer_video('/content/Lab_11/test/images/(BMW M5) #bmw #automobile #crash #supercars - DriftX (360p, h264).mp4', 'segmented_output_video.mp4')
# Out:
# 0: 640x384 (no detections), 66.2ms
# Speed: 2.9ms preprocess, 66.2ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 10.8ms
# Speed: 3.3ms preprocess, 10.8ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 10.9ms
# Speed: 1.7ms preprocess, 10.9ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 Car-Damage, 10.6ms
# Speed: 1.7ms preprocess, 10.6ms inference, 2.7ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 15.6ms
# Speed: 1.6ms preprocess, 15.6ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 21.8ms
# Speed: 1.9ms preprocess, 21.8ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 11.1ms
# Speed: 1.6ms preprocess, 11.1ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 10.8ms
# ...

# %%
# Task

# %%
# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="1g3h8ta3LmsV3xdVpxj3")
project = rf.workspace("giki-uue7v").project("segmentation_lab11-89dkz")
version = project.version(1)
dataset = version.download("yolov11")
# Out:
# ...
# loading Roboflow workspace...
# loading Roboflow project...

# %%
pip install ultralytics

# %%
# !unzip /content/Segmentation_Lab11.v1i.yolov11.zip
# Out:
# Archive:  /content/Segmentation_Lab11.v1i.yolov11.zip
#   inflating: README.dataset.txt
#   inflating: README.roboflow.txt
#   inflating: data.yaml
#    creating: test/
#    creating: test/images/
#  extracting: test/images/WhatsApp-Video-2025-08-09-at-4_19_20-PM_mp4-0004_jpg.rf.410e73e77b3679c787d13e83e69b995e.jpg
#  extracting: test/images/WhatsApp-Video-2025-08-09-at-4_19_20-PM_mp4-0008_jpg.rf.3e361c914a86271a7b697bae3be6351c.jpg
#  extracting: test/images/WhatsApp-Video-2025-08-09-at-4_19_20-PM_mp4-0009_jpg.rf.dba54985bff193c43c4583a3edb21bf7.jpg
#  extracting: test/images/WhatsApp-Video-2025-08-09-at-4_19_20-PM_mp4-0010_jpg.rf.6eabf4da827a34375ad1fc98d2e2a19c.jpg
#  extracting: test/images/WhatsApp-Video-2025-08-09-at-4_19_20-PM_mp4-0013_jpg.rf.4dcdd870e458b5120923298b3f952078.jpg
#  extracting: test/images/WhatsApp-Video-2025-08-09-at-4_19_20-PM_mp4-0019_jpg.rf.5e1e26de2bbed7c12072c0039a96747a.jpg
# ...

# %%
# !unzip /content/Lab_11_task/Task11.v1i.yolov11.zip
# Out:
# Archive:  /content/Lab_11_task/Task11.v1i.yolov11.zip
#   inflating: README.dataset.txt
#   inflating: README.roboflow.txt
#   inflating: data.yaml
#    creating: test/
#    creating: test/images/
#  extracting: test/images/WhatsApp-Video-2025-08-10-at-6_58_19-PM_mp4-0001_jpg.rf.ac605122e0f61ffe3667a4b912283671.jpg
#  extracting: test/images/WhatsApp-Video-2025-08-10-at-6_58_19-PM_mp4-0015_jpg.rf.d049a265b9b900c29c4b58fffbc69f43.jpg
#  extracting: test/images/WhatsApp-Video-2025-08-10-at-6_58_19-PM_mp4-0020_jpg.rf.eb2f7663d8dcac202033e84f12d1c4ba.jpg
#  extracting: test/images/WhatsApp-Video-2025-08-10-at-6_58_19-PM_mp4-0027_jpg.rf.272ef2d785ecc0e0b4f919e68647a4ff.jpg
#  extracting: test/images/WhatsApp-Video-2025-08-10-at-6_58_19-PM_mp4-0033_jpg.rf.81d4ef86dc1629c19daa8aeae936d247.jpg
#  extracting: test/images/WhatsApp-Video-2025-08-10-at-6_58_19-PM_mp4-0036_jpg.rf.9860b5cd905e9ebd6da1f93e9e009aba.jpg
# ...

# %%
from ultralytics import YOLO

# Load YOLOv11 segmentation model (pretrained)
model = YOLO("yolo11n-seg.pt")   # small model
# or
# model = YOLO("yolo11s-seg.pt") # slightly bigger
# model = YOLO("yolo11m-seg.pt") # medium
# model = YOLO("yolo11l-seg.pt") # large

# Train
model.train(
    data="data.yaml",
    epochs=50,
    imgsz=640,
    batch=8
)
# Out:
# ...
# Ultralytics 8.3.176 🚀 Python-3.11.13 torch-2.6.0+cu124 CUDA:0 (Tesla T4, 15095MiB)
# ...

# %%
from ultralytics import YOLO
model = YOLO("/content/Lab_11_task/runs/segment/train/weights/best.pt")
model.val(data="/content/Lab_11_task/data.yaml")
# Out:
# Ultralytics 8.3.176 🚀 Python-3.11.13 torch-2.6.0+cu124 CUDA:0 (Tesla T4, 15095MiB)
# YOLO11n-seg summary (fused): 113 layers, 2,835,933 parameters, 0 gradients, 10.2 GFLOPs
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 1259.2±452.9 MB/s, size: 33.7 KB)
# val: Scanning /content/Lab_11_task/valid/labels.cache... 7 images, 0 backgrounds, 0 corrupt: 100%|██████████| 7/7 [00:00<?, ?it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95):   0%|          | 0/1 [00:00<?, ?it/s]
# WARNING ⚠️ Limiting validation plots to first 50 items per image for speed...
# WARNING ⚠️ Limiting validation plots to first 50 items per image for speed...
# WARNING ⚠️ Limiting validation plots to first 50 items per image for speed...
# WARNING ⚠️ Limiting validation plots to first 50 items per image for speed...
# WARNING ⚠️ Limiting validation plots to first 50 items per image for speed...
# ...

# %%
results = model.predict(source="/content/Lab_11_task/test/images/WhatsApp-Video-2025-08-10-at-6_58_19-PM_mp4-0001_jpg.rf.ac605122e0f61ffe3667a4b912283671.jpg", save=True, conf=0.25)
# Out:
# image 1/1 /content/Lab_11_task/test/images/WhatsApp-Video-2025-08-10-at-6_58_19-PM_mp4-0001_jpg.rf.ac605122e0f61ffe3667a4b912283671.jpg: 640x640 1 Handsfree, 13.3ms
# Speed: 2.5ms preprocess, 13.3ms inference, 15.2ms postprocess per image at shape (1, 3, 640, 640)
# Results saved to runs/segment/predict

# %%
# Function for inference on a video
def infer_video(video_path, output_path="output_video.mp4"):
    # Open the video file
    cap = cv2.VideoCapture(video_path)
    if not cap.isOpened():
        print(f"Error: Could not open video at {video_path}")
        return

    # Get video properties
    width = int(cap.get(cv2.CAP_PROP_FRAME_WIDTH))
    height = int(cap.get(cv2.CAP_PROP_FRAME_HEIGHT))
    fps = int(cap.get(cv2.CAP_PROP_FPS))

    # Define the codec and create VideoWriter object
    fourcc = cv2.VideoWriter_fourcc(*'mp4v')
    out = cv2.VideoWriter(output_path, fourcc, fps, (width, height))

    # Process video frame by frame
    while cap.isOpened():
        ret, frame = cap.read()
        if not ret:
            break

        # Perform inference on the frame
        results = model(frame)

        # Draw bounding boxes and labels on the frame
        annotated_frame = results[0].plot()

        # Write the frame to the output video
        out.write(annotated_frame)

    # Release resources
    cap.release()
    out.release()
    #cv2.destroyAllWindows()
    print(f"Output video saved at {output_path}")

# %%
infer_video('/content/Lab_11_task/WhatsApp Video 2025-08-10 at 6.58.19 PM.mp4', 'segmented_output_video1.mp4')
# Out:
# 0: 640x384 1 Handsfree, 59.1ms
# Speed: 4.1ms preprocess, 59.1ms inference, 2.7ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 Handsfree, 13.0ms
# Speed: 3.3ms preprocess, 13.0ms inference, 2.7ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 Handsfree, 11.0ms
# Speed: 2.7ms preprocess, 11.0ms inference, 2.3ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 Handsfree, 10.0ms
# Speed: 1.8ms preprocess, 10.0ms inference, 2.2ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 Handsfree, 10.0ms
# Speed: 2.9ms preprocess, 10.0ms inference, 2.1ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 Handsfree, 10.3ms
# Speed: 2.8ms preprocess, 10.3ms inference, 2.3ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 Handsfree, 10.1ms
# Speed: 2.8ms preprocess, 10.1ms inference, 2.2ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 Handsfree, 10.8ms
# ...

# %%
# !zip -r /content/Lab_11_task /content
# Out:
#   adding: content/ (stored 0%)
#   adding: content/.config/ (stored 0%)
#   adding: content/.config/active_config (stored 0%)
#   adding: content/.config/.last_survey_prompt.yaml (stored 0%)
#   adding: content/.config/.last_update_check.json (deflated 22%)
#   adding: content/.config/.last_opt_in_prompt.yaml (stored 0%)
#   adding: content/.config/gce (stored 0%)
#   adding: content/.config/configurations/ (stored 0%)
#   adding: content/.config/configurations/config_default (deflated 15%)
#   adding: content/.config/default_configs.db (deflated 98%)
#   adding: content/.config/logs/ (stored 0%)
#   adding: content/.config/logs/2025.08.07/ (stored 0%)
#   adding: content/.config/logs/2025.08.07/13.42.07.355819.log (deflated 58%)
#   adding: content/.config/logs/2025.08.07/13.42.26.351069.log (deflated 56%)
#   adding: content/.config/logs/2025.08.07/13.42.17.248935.log (deflated 58%)
#   adding: content/.config/logs/2025.08.07/13.41.46.739789.log (deflated 92%)
# ...

# %%
from google.colab import files
files.download("yolo_project.zip")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipython-input-2615803958.py in <cell line: 0>()
#       2
#       3 # Replace with your actual file name
# ----> 4 files.download("your_file_name.ipynb")
#
# /usr/local/lib/python3.11/dist-packages/google/colab/files.py in download(filename)
#     231   if not _os.path.exists(filename):
#     232     msg = 'Cannot find file: {}'.format(filename)
# --> 233     raise FileNotFoundError(msg)  # pylint: disable=undefined-variable
#     234
#     235   comm_manager = _IPython.get_ipython().kernel.comm_manager
#
# FileNotFoundError: Cannot find file: your_file_name.ipynb

# %% [markdown]
# ### Next
#
# Task:
